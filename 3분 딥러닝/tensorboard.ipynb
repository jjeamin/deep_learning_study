# %% [markdown]
# # 텐서보드

# %%
import tensorflow as tf
import numpy as np

data = np.loadtxt('./data.csv', delimiter=',',
                  unpack=True, dtype='float32')

x_data = np.transpose(data[0:2])
y_data = np.transpose(data[2:])

#########
# 신경망 모델 구성
######
global_step = tf.Variable(0, trainable=False, name='global_step')

X = tf.placeholder(tf.float32)
Y = tf.placeholder(tf.float32)

with tf.name_scope('layer1'):
    W1 = tf.Variable(tf.random_uniform([2, 10], -1., 1.), name='W1')
    L1 = tf.nn.relu(tf.matmul(X, W1))

    tf.summary.histogram("X", X)
    tf.summary.histogram("Weights", W1)

with tf.name_scope('layer2'):
    W2 = tf.Variable(tf.random_uniform([10, 20], -1., 1.), name='W2')
    L2 = tf.nn.relu(tf.matmul(L1, W2))

    tf.summary.histogram("Weights", W2)

with tf.name_scope('output'):
    W3 = tf.Variable(tf.random_uniform([20, 3], -1., 1.), name='W3')
    model = tf.matmul(L2, W3)

    tf.summary.histogram("Weights", W3)
    tf.summary.histogram("Model", model)

with tf.name_scope('optimizer'):
    cost = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits_v2(labels=Y, logits=model))

    optimizer = tf.train.AdamOptimizer(learning_rate=0.01)
    train_op = optimizer.minimize(cost, global_step=global_step)

    tf.summary.scalar('cost', cost)

#########
# 신경망 모델 학습
######
sess = tf.Session()
saver = tf.train.Saver(tf.global_variables())

ckpt = tf.train.get_checkpoint_state('./model')
if ckpt and tf.train.checkpoint_exists(ckpt.model_checkpoint_path):
    saver.restore(sess, ckpt.model_checkpoint_path)
else:
    sess.run(tf.global_variables_initializer())

merged = tf.summary.merge_all()
writer = tf.summary.FileWriter('./logs', sess.graph)

for step in range(100):
    sess.run(train_op, feed_dict={X: x_data, Y: y_data})

    print('Step: %d, ' % sess.run(global_step),
          'Cost: %.3f' % sess.run(cost, feed_dict={X: x_data, Y: y_data}))

    summary = sess.run(merged, feed_dict={X: x_data, Y: y_data})
    writer.add_summary(summary, global_step=sess.run(global_step))

saver.save(sess, './model/dnn.ckpt', global_step=global_step)

#########
# 결과 확인
######
prediction = tf.argmax(model, 1)
target = tf.argmax(Y, 1)
print('예측값:', sess.run(prediction, feed_dict={X: x_data}))
print('실제값:', sess.run(target, feed_dict={Y: y_data}))

is_correct = tf.equal(prediction, target)
accuracy = tf.reduce_mean(tf.cast(is_correct, tf.float32))
print('정확도: %.2f' % sess.run(accuracy * 100, feed_dict={X: x_data, Y: y_data}))
# Out:
# Step: 1,  Cost: 1.085
# Step: 2,  Cost: 1.054
# Step: 3,  Cost: 1.029
# Step: 4,  Cost: 1.007
# Step: 5,  Cost: 0.988
# Step: 6,  Cost: 0.971
# Step: 7,  Cost: 0.955
# Step: 8,  Cost: 0.942
# Step: 9,  Cost: 0.930
# Step: 10,  Cost: 0.921
# Step: 11,  Cost: 0.913
# Step: 12,  Cost: 0.905
# Step: 13,  Cost: 0.897
# Step: 14,  Cost: 0.889
# Step: 15,  Cost: 0.881
# Step: 16,  Cost: 0.872
# Step: 17,  Cost: 0.862
# Step: 18,  Cost: 0.852
# Step: 19,  Cost: 0.842
# Step: 20,  Cost: 0.832
# Step: 21,  Cost: 0.823
# Step: 22,  Cost: 0.813
# Step: 23,  Cost: 0.804
# Step: 24,  Cost: 0.795
# Step: 25,  Cost: 0.785
# Step: 26,  Cost: 0.774
# Step: 27,  Cost: 0.762
# Step: 28,  Cost: 0.749
# Step: 29,  Cost: 0.736
# Step: 30,  Cost: 0.722
# Step: 31,  Cost: 0.708
# Step: 32,  Cost: 0.694
# Step: 33,  Cost: 0.681
# Step: 34,  Cost: 0.668
# Step: 35,  Cost: 0.656
# Step: 36,  Cost: 0.645
# Step: 37,  Cost: 0.635
# Step: 38,  Cost: 0.625
# Step: 39,  Cost: 0.616
# Step: 40,  Cost: 0.608
# Step: 41,  Cost: 0.601
# Step: 42,  Cost: 0.594
# Step: 43,  Cost: 0.588
# Step: 44,  Cost: 0.583
# Step: 45,  Cost: 0.579
# Step: 46,  Cost: 0.575
# Step: 47,  Cost: 0.572
# Step: 48,  Cost: 0.569
# Step: 49,  Cost: 0.567
# Step: 50,  Cost: 0.565
# Step: 51,  Cost: 0.563
# Step: 52,  Cost: 0.562
# Step: 53,  Cost: 0.560
# Step: 54,  Cost: 0.559
# Step: 55,  Cost: 0.558
# Step: 56,  Cost: 0.557
# Step: 57,  Cost: 0.557
# Step: 58,  Cost: 0.556
# Step: 59,  Cost: 0.556
# Step: 60,  Cost: 0.555
# Step: 61,  Cost: 0.555
# Step: 62,  Cost: 0.554
# Step: 63,  Cost: 0.554
# Step: 64,  Cost: 0.554
# Step: 65,  Cost: 0.553
# Step: 66,  Cost: 0.553
# Step: 67,  Cost: 0.553
# Step: 68,  Cost: 0.553
# Step: 69,  Cost: 0.553
# Step: 70,  Cost: 0.553
# Step: 71,  Cost: 0.552
# Step: 72,  Cost: 0.552
# Step: 73,  Cost: 0.552
# Step: 74,  Cost: 0.552
# Step: 75,  Cost: 0.552
# Step: 76,  Cost: 0.552
# Step: 77,  Cost: 0.552
# Step: 78,  Cost: 0.552
# Step: 79,  Cost: 0.552
# Step: 80,  Cost: 0.552
# Step: 81,  Cost: 0.551
# Step: 82,  Cost: 0.551
# Step: 83,  Cost: 0.551
# Step: 84,  Cost: 0.551
# Step: 85,  Cost: 0.551
# Step: 86,  Cost: 0.551
# Step: 87,  Cost: 0.551
# Step: 88,  Cost: 0.551
# Step: 89,  Cost: 0.551
# Step: 90,  Cost: 0.551
# Step: 91,  Cost: 0.551
# Step: 92,  Cost: 0.551
# Step: 93,  Cost: 0.551
# Step: 94,  Cost: 0.551
# Step: 95,  Cost: 0.551
# Step: 96,  Cost: 0.551
# Step: 97,  Cost: 0.551
# Step: 98,  Cost: 0.551
# Step: 99,  Cost: 0.551
# Step: 100,  Cost: 0.551
# 예측값: [0 1 2 0 0 2]
# 실제값: [0 1 2 0 0 2]
# 정확도: 100.00

# %%
import tensorflow as tf
import numpy as np

data = np.loadtxt('./data.csv', delimiter=',',
                  unpack=True, dtype='float32')

x_data = np.transpose(data[0:2])
y_data = np.transpose(data[2:])

#########
# 신경망 모델 구성
######
global_step = tf.Variable(0, trainable=False, name='global_step')

X = tf.placeholder(tf.float32)
Y = tf.placeholder(tf.float32)

with tf.name_scope('layer1'):
    W1 = tf.Variable(tf.random_uniform([2, 10], -1., 1.), name='W1')
    L1 = tf.nn.relu(tf.matmul(X, W1))

    tf.summary.histogram("X", X)
    tf.summary.histogram("Weights", W1)

with tf.name_scope('layer2'):
    W2 = tf.Variable(tf.random_uniform([10, 20], -1., 1.), name='W2')
    L2 = tf.nn.relu(tf.matmul(L1, W2))

    tf.summary.histogram("Weights", W2)

with tf.name_scope('output'):
    W3 = tf.Variable(tf.random_uniform([20, 3], -1., 1.), name='W3')
    model = tf.matmul(L2, W3)

    tf.summary.histogram("Weights", W3)
    tf.summary.histogram("Model", model)

with tf.name_scope('optimizer'):
    cost = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits_v2(labels=Y, logits=model))

    optimizer = tf.train.AdamOptimizer(learning_rate=0.01)
    train_op = optimizer.minimize(cost, global_step=global_step)

    tf.summary.scalar('cost', cost)

#########
# 신경망 모델 학습
######
sess = tf.Session()

merged = tf.summary.merge_all()
writer = tf.summary.FileWriter('./logs', sess.graph)

for step in range(100):
    sess.run(train_op, feed_dict={X: x_data, Y: y_data})

    print('Step: %d, ' % sess.run(global_step),
          'Cost: %.3f' % sess.run(cost, feed_dict={X: x_data, Y: y_data}))

    summary = sess.run(merged, feed_dict={X: x_data, Y: y_data})
    writer.add_summary(summary, global_step=sess.run(global_step))

#########
# 결과 확인
######
prediction = tf.argmax(model, 1)
target = tf.argmax(Y, 1)
print('예측값:', sess.run(prediction, feed_dict={X: x_data}))
print('실제값:', sess.run(target, feed_dict={Y: y_data}))

is_correct = tf.equal(prediction, target)
accuracy = tf.reduce_mean(tf.cast(is_correct, tf.float32))
print('정확도: %.2f' % sess.run(accuracy * 100, feed_dict={X: x_data, Y: y_data}))
# Out:
# ---------------------------------------------------------------------------
# FailedPreconditionError                   Traceback (most recent call last)
# ~\AppData\Local\conda\conda\envs\py35_64\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1277     try:
# -> 1278       return fn(*args)
#    1279     except errors.OpError as e:
#
# ~\AppData\Local\conda\conda\envs\py35_64\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1262       return self._call_tf_sessionrun(
# -> 1263           options, feed_dict, fetch_list, target_list, run_metadata)
#    1264
#
# ~\AppData\Local\conda\conda\envs\py35_64\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1349         self._session, options, feed_dict, fetch_list, target_list,
# -> 1350         run_metadata)
#    1351
#
# FailedPreconditionError: Attempting to use uninitialized value output_1/W3
# 	 [[Node: output_1/W3/read = Identity[T=DT_FLOAT, _class=["loc:@optimizer_1/Adam/update_output_1/W3/ApplyAdam"], _device="/job:localhost/replica:0/task:0/device:CPU:0"](output_1/W3)]]
#
# During handling of the above exception, another exception occurred:
#
# FailedPreconditionError                   Traceback (most recent call last)
# <ipython-input-2-5170ddab63d3> in <module>()
#      54
#      55 for step in range(100):
# ---> 56     sess.run(train_op, feed_dict={X: x_data, Y: y_data})
#      57
#      58     print('Step: %d, ' % sess.run(global_step),
#
# ~\AppData\Local\conda\conda\envs\py35_64\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     875     try:
#     876       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 877                          run_metadata_ptr)
#     878       if run_metadata:
#     879         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\AppData\Local\conda\conda\envs\py35_64\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1098     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1099       results = self._do_run(handle, final_targets, final_fetches,
# -> 1100                              feed_dict_tensor, options, run_metadata)
#    1101     else:
#    1102       results = []
#
# ~\AppData\Local\conda\conda\envs\py35_64\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1270     if handle is None:
#    1271       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1272                            run_metadata)
#    1273     else:
#    1274       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~\AppData\Local\conda\conda\envs\py35_64\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1289         except KeyError:
#    1290           pass
# -> 1291       raise type(e)(node_def, op, message)
#    1292
#    1293   def _extend_graph(self):
#
# FailedPreconditionError: Attempting to use uninitialized value output_1/W3
# 	 [[Node: output_1/W3/read = Identity[T=DT_FLOAT, _class=["loc:@optimizer_1/Adam/update_output_1/W3/ApplyAdam"], _device="/job:localhost/replica:0/task:0/device:CPU:0"](output_1/W3)]]
#
# Caused by op 'output_1/W3/read', defined at:
#   File "C:\Users\woals\AppData\Local\conda\conda\envs\py35_64\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\woals\AppData\Local\conda\conda\envs\py35_64\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\woals\AppData\Local\conda\conda\envs\py35_64\lib\site-packages\ipykernel\__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "C:\Users\woals\AppData\Local\conda\conda\envs\py35_64\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\woals\AppData\Local\conda\conda\envs\py35_64\lib\site-packages\ipykernel\kernelapp.py", line 497, in start
#     self.io_loop.start()
#   File "C:\Users\woals\AppData\Local\conda\conda\envs\py35_64\lib\site-packages\tornado\platform\asyncio.py", line 132, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\woals\AppData\Local\conda\conda\envs\py35_64\lib\asyncio\base_events.py", line 421, in run_forever
#     self._run_once()
#   File "C:\Users\woals\AppData\Local\conda\conda\envs\py35_64\lib\asyncio\base_events.py", line 1425, in _run_once
#     handle._run()
#   File "C:\Users\woals\AppData\Local\conda\conda\envs\py35_64\lib\asyncio\events.py", line 127, in _run
#     self._callback(*self._args)
#   File "C:\Users\woals\AppData\Local\conda\conda\envs\py35_64\lib\site-packages\tornado\platform\asyncio.py", line 122, in _handle_events
#     handler_func(fileobj, events)
#   File "C:\Users\woals\AppData\Local\conda\conda\envs\py35_64\lib\site-packages\tornado\stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\woals\AppData\Local\conda\conda\envs\py35_64\lib\site-packages\zmq\eventloop\zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "C:\Users\woals\AppData\Local\conda\conda\envs\py35_64\lib\site-packages\zmq\eventloop\zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Users\woals\AppData\Local\conda\conda\envs\py35_64\lib\site-packages\zmq\eventloop\zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Users\woals\AppData\Local\conda\conda\envs\py35_64\lib\site-packages\tornado\stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\woals\AppData\Local\conda\conda\envs\py35_64\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Users\woals\AppData\Local\conda\conda\envs\py35_64\lib\site-packages\ipykernel\kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Users\woals\AppData\Local\conda\conda\envs\py35_64\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Users\woals\AppData\Local\conda\conda\envs\py35_64\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\woals\AppData\Local\conda\conda\envs\py35_64\lib\site-packages\ipykernel\zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\woals\AppData\Local\conda\conda\envs\py35_64\lib\site-packages\IPython\core\interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "C:\Users\woals\AppData\Local\conda\conda\envs\py35_64\lib\site-packages\IPython\core\interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\woals\AppData\Local\conda\conda\envs\py35_64\lib\site-packages\IPython\core\interactiveshell.py", line 2901, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Users\woals\AppData\Local\conda\conda\envs\py35_64\lib\site-packages\IPython\core\interactiveshell.py", line 2961, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-5170ddab63d3>", line 32, in <module>
#     W3 = tf.Variable(tf.random_uniform([20, 3], -1., 1.), name='W3')
#   File "C:\Users\woals\AppData\Local\conda\conda\envs\py35_64\lib\site-packages\tensorflow\python\ops\variables.py", line 259, in __init__
#     constraint=constraint)
#   File "C:\Users\woals\AppData\Local\conda\conda\envs\py35_64\lib\site-packages\tensorflow\python\ops\variables.py", line 422, in _init_from_args
#     self._snapshot = array_ops.identity(self._variable, name="read")
#   File "C:\Users\woals\AppData\Local\conda\conda\envs\py35_64\lib\site-packages\tensorflow\python\ops\array_ops.py", line 80, in identity
#     return gen_array_ops.identity(input, name=name)
#   File "C:\Users\woals\AppData\Local\conda\conda\envs\py35_64\lib\site-packages\tensorflow\python\ops\gen_array_ops.py", line 3888, in identity
#     "Identity", input=input, name=name)
#   File "C:\Users\woals\AppData\Local\conda\conda\envs\py35_64\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "C:\Users\woals\AppData\Local\conda\conda\envs\py35_64\lib\site-packages\tensorflow\python\util\deprecation.py", line 454, in new_func
#     return func(*args, **kwargs)
#   File "C:\Users\woals\AppData\Local\conda\conda\envs\py35_64\lib\site-packages\tensorflow\python\framework\ops.py", line 3155, in create_op
#     op_def=op_def)
#   File "C:\Users\woals\AppData\Local\conda\conda\envs\py35_64\lib\site-packages\tensorflow\python\framework\ops.py", line 1717, in __init__
#     self._traceback = tf_stack.extract_stack()
#
# FailedPreconditionError (see above for traceback): Attempting to use uninitialized value output_1/W3
# 	 [[Node: output_1/W3/read = Identity[T=DT_FLOAT, _class=["loc:@optimizer_1/Adam/update_output_1/W3/ApplyAdam"], _device="/job:localhost/replica:0/task:0/device:CPU:0"](output_1/W3)]]
